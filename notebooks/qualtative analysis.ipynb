# %%
import os
import sys

# %%
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
from  scripts.utils import data_loader
from scripts.qualitative import *
from scripts.visualization import *

# %%
news_data = data_loader(os.path.dirname(os.getcwd()) + "\\data\\raw_analyst_ratings.csv")

# %%
headline_length(news_data)
# Out:
# 0          39
# 1          42
# 2          29
# 3          44
# 4          87
#            ..
# 1407323    38
# 1407324    52
# 1407325    56
# 1407326    54
# 1407327    81
# Name: headline, Length: 1407328, dtype: int64

# %%
words_per_headline(news_data)
# Out:
# 0           7
# 1           7
# 2           5
# 3           7
# 4          14
#            ..
# 1407323     7
# 1407324     7
# 1407325     8
# 1407326     8
# 1407327    14
# Name: headline, Length: 1407328, dtype: int64

# %%
stats(news_data)
# Out:
#        headline length  word count per headline
# count     1.407328e+06             1.407328e+06
# mean      7.312051e+01             1.141671e+01
# std       4.073531e+01             6.352997e+00
# min       3.000000e+00             1.000000e+00
# 25%       4.700000e+01             7.000000e+00
# 50%       6.400000e+01             1.000000e+01
# 75%       8.700000e+01             1.300000e+01
# max       5.120000e+02             7.700000e+01

# %%
most_frequent_word(news_data,3)
# Out:
# [('stocks', 159102), ('vs', 138801), ('eps', 127403)]

# %%
articles_per_publisher(news_data)
# Out:
#                   publisher  article_count
# 686           Paul Quintaro         228373
# 532              Lisa Levin         186979
# 96        Benzinga Newsdesk         150484
# 169           Charles Gross          96732
# 622           Monica Gerson          82380
# ..                      ...            ...
# 628  MyConstant Chris Roper              1
# 998              milesyoung              1
# 632                     Nat              1
# 999           mjintertrader              1
# 15              Adam Weiner              1
#
# [1034 rows x 2 columns]

# %%
sentiment(news_data)
# Out:
#                                                   headline  sentiment  \
# 0                  Stocks That Hit 52-Week Highs On Friday       0.00
# 1               Stocks That Hit 52-Week Highs On Wednesday       0.00
# 2                            71 Biggest Movers From Friday       0.00
# 3             46 Stocks Moving In Friday's Mid-Day Session       0.00
# 4        B of A Securities Maintains Neutral on Agilent...       0.00
# ...                                                    ...        ...
# 1407323             Top Narrow Based Indexes For August 29       0.15
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...       0.15
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...       0.00
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...       0.00
# 1407327  China Zenix Auto International Opens For Tradi...       0.00
#
#         sentiment_category
# 0                  neutral
# 1                  neutral
# 2                  neutral
# ...

# %%
articls_per_publisher(news_data,5)

# %%
word_cloud(news_data)

# %%
topic_per_publisher(news_data, 5)

# %%
articles_per_topic(news_data)

# %%
articles_by_email_domian(news_data)

# %%
sentiment_per_publisher(news_data,5)

# %%
news_data['date'] = pd.to_datetime(news_data['date'], format = 'ISO8601')

# %%
article_per_day_of_week(news_data)
# Out:
# c:\Users\esk\Desktop\10 acadamy\repo\stock-analysis\scripts\visualization.py:137: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=day_counts.index, y=day_counts.values, palette='viridis')

# %%
article_per_hour(news_data)

# %%
articles_per_month(news_data)
# Out:
# c:\Users\esk\Desktop\10 acadamy\repo\stock-analysis\scripts\visualization.py:165: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=month_counts.index, y=month_counts.values, palette='coolwarm')

# %%
#publication frequency over time
publication_freq_wrt_t(news_data)
